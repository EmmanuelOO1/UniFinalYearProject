# %%
import pandas as pd 
# importing

# %%
data = pd.read_csv("accelerometer.txt")
# reading the data in the acc file and asignling it to a variable

# %%
data.head()
# checking the formatting of the acc file, in order to make sure it can be analysed
# Out:
#           X         Y         Z
# 0  0.006424 -0.013908 -0.008651
# 1  0.009824  0.002398 -0.001821
# 2  0.002761 -0.017706 -0.004179
# 3  0.020937 -0.010307 -0.007900
# 4  0.021656  0.025432  0.015090

# %%
# %matplotlib inline
# Allows me to display the generated plots directly within a Jupyter Notebook environment

# %%
data.plot(y="X")
#graphing the X co ordinants of the accelerometer
# Out:
# <Axes: >

# %%
data.plot(y="Y")
#graphing the Y co ordinants of the accelerometer
# Out:
# <Axes: >

# %%
data.plot(y="Z")
#graphing the Z co ordinants of the accelerometer
# Out:
# <Axes: >
